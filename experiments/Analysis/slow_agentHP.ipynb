# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from experiments.Analysis.maddpgRewards import recent_rewards

# %%
R0, _, R0t = recent_rewards('../learning_curves/slow_agent_I1.75.0.01.128.1.0.FA.FL')
R1, _, R1t = recent_rewards('../learning_curves/slow_agent_I1_R1.50.0.01.128.1.0.FA.FL')
R2, _, R2t = recent_rewards('../learning_curves/slow_agent_I1_R2.75.0.01.128.1.0.FA.FL')
R3, _, R3t = recent_rewards('../learning_curves/slow_agent_I1_R3.75.0.01.128.1.0.FA.FL')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/l2/bsmxrkc10x736tqpcsz1q6mw0000gp/T/ipykernel_49153/4067939375.py in <module>
# ----> 1 R0, _, R0t = recent_rewards('../learning_curves/slow_agent_I1.75.0.01.128.1.0.FA.FL')
#       2 R1, _, R1t = recent_rewards('../learning_curves/slow_agent_I1_R1.50.0.01.128.1.0.FA.FL')
#       3 R2, _, R2t = recent_rewards('../learning_curves/slow_agent_I1_R2.75.0.01.128.1.0.FA.FL')
#       4 R3, _, R3t = recent_rewards('../learning_curves/slow_agent_I1_R3.75.0.01.128.1.0.FA.FL')
#       5
#
# ~/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/Analysis/maddpgRewards.py in recent_rewards(base_path, aggrew, valid)
#      37     """Get the rewards from the most recent directory."""
#      38     # Get the directories
# ---> 39     directories = get_directories(base_path)
#      40     # Filter out the directories that don't match the date and time pattern
#      41     date_directories = filter_directories_by_date(directories, date_format)
#
# ~/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/Analysis/maddpgRewards.py in get_directories(base_path)
#       9 def get_directories(base_path):
#      10     """Get a list of all directories in the base path."""
# ---> 11     return [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]
#      12 def filter_directories_by_date(directories, date_format):
#      13     """Filter out directories that match the date and time pattern."""
#
# FileNotFoundError: [Errno 2] No such file or directory: '../learning_curves/slow_agent_I1.75.0.01.128.1.0.FA.FL'

# %%
plt.plot(R0, label='R0')
plt.legend()

plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Ant 2x4')
plt.savefig('../plots/slow_agent_changing_reward_R0.png')

# %%
plt.plot(R1, label='R1')
plt.legend()

plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent | Changing reward function R1')
plt.savefig('../plots/slow_agent_changing_reward_R1.png')

# %%
plt.plot(R2, label='R2')
plt.legend()

plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent | Changing reward function R2')
plt.savefig('../plots/slow_agent_changing_reward_R2.png')

# %%
plt.plot(R3, label='R3')
plt.legend()
# plt.ylim(-2000,1000)

plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent | Changing reward function R3')
plt.savefig('../plots/slow_agent_changing_reward_R3.png')

# %%
FAFL1,_,FAFL1t =recent_rewards('../learning_curves/slow_agent.50.0.01.128.1.0.FA.FL')
FANFL1,_,FANFL1t =recent_rewards('../learning_curves/slow_agent.50.0.01.128.1.0.FA.NFL')
NFANFL1,_,NFANFL1t =recent_rewards('../learning_curves/slow_agent.50.0.01.128.1.0.NFA.NFL')
NFAFL1,_,NFAFL1t =recent_rewards('../learning_curves/slow_agent.50.0.01.128.1.0.NFA.FL')
FAFL,_,FAFLt = recent_rewards('../learning_curves/slow_agent.50.0.01.128.0.95.FA.FL', valid=False)
FANFL,_,FANFLt = recent_rewards('../learning_curves/slow_agent.50.0.01.128.0.95.FA.NFL', valid=False)
NFANFL,_,NFANFLt = recent_rewards('../learning_curves/slow_agent.50.0.01.128.0.95.NFA.NFL', valid=False)
NFAFL,_,NFAFLt = recent_rewards('../learning_curves/slow_agent.50.0.01.128.0.95.NFA.FL', valid=False)
FAFL1_I1,_,FAFL1t =recent_rewards('../learning_curves/slow_agent_I1.50.0.01.128.1.0.FA.FL')
FANFL1_I1,_,FANFL1t =recent_rewards('../learning_curves/slow_agent_I1.50.0.01.128.1.0.FA.NFL')
NFANFL1_I1,_,NFANFL1t =recent_rewards('../learning_curves/slow_agent_I1.50.0.01.128.1.0.NFA.NFL')
NFAFL1_I1,_,NFAFL1t =recent_rewards('../learning_curves/slow_agent_I1.50.0.01.128.1.0.NFA.FL')

# %%
# Now you can plot the data
# For example, plot the rewards
plt.figure(figsize=(10, 5))
plt.plot(FAFL, label='FAFL')
plt.plot(FANFL, label= 'FANFL')
plt.plot(NFANFL, label= 'NFANFL')
plt.plot(NFAFL, label='NFAFL')

# plt.ylim(-20,0)
plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent | Changing fixed nature')
plt.savefig('../plots/slow_agent_changing_fixed_nature.png')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(FAFL, label='FAFL - 0.95')
plt.plot(FANFL, label= 'FANFL - 0.95')
plt.plot(NFANFL, label= 'NFANFL- 0.95')
plt.plot(NFAFL, label='NFAFL - 0.95')
plt.plot(FAFL1, label='FAFL - 1')
plt.plot(FANFL1, label= 'FANFL - 1')
plt.plot(NFANFL1, label= 'NFANFL - 1')
plt.plot(NFAFL1, label='NFAFL - 1')


# plt.ylim(-20,0)
plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent')

plt.show()

# %%
category_names = ['FAFL', 'FANFL', 'NFANFL', 'NFAFL']
results = {
    'FAFL': np.sum(FAFL1t),
    'FANFL': np.sum(FANFL1t),
    'NFANFL': np.sum(NFANFL1t),
    'NFAFL': np.sum(NFAFL1t)
}
plt.bar(category_names, results.values(), color=['red', 'green', 'blue', 'orange'])
plt.ylim(0, 1000)
plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent with L1 location | Amount of time slow agent reaches landmark')
plt.savefig('../plots/slow_agent_L1_success.png')

# %%
FANFL32 = recent_rewards('../learning_curves/slow_agent.50.0.01.32.0.95.FA.NFL')
FANFL64 = recent_rewards('../learning_curves/slow_agent.50.0.01.64.1.0.FA.NFL')
FANFL128 = recent_rewards('../learning_curves/slow_agent.50.0.01.128.1.0.FA.NFL')
FANFL256 = recent_rewards('../learning_curves/slow_agent.50.0.01.256.1.0.FA.NFL')

# %%
plt.figure(figsize=(10, 5))
plt.plot(FANFL32[0], label= 'FANFL - 32')
plt.plot(FANFL64[0], label= 'FANFL - 64')
plt.plot(FANFL128[0], label= 'FANFL - 128')
plt.plot(FANFL256[0], label= 'FANFL - 256')

# plt.ylim(-20,0)
plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent')
plt.savefig('../plots/FANFL_nwsize.png')

# %%
plt.plot(NFANFL1_I1, label= 'NFANFL - I1')
plt.plot(NFANFL1, label= 'NFANFL - I0')

plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent')
plt.savefig('../plots/location/NFANFL_I1vOG.png')

# %%
plt.plot(NFAFL1_I1, label= 'NFAFL - I1')
plt.plot(NFAFL1, label= 'NFAFL - I0')

plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent')
plt.savefig('../plots/location/NFAFL_I1vOG.png')

# %%
plt.plot(FANFL1_I1, label= 'FANFL - I1')
plt.plot(FANFL1, label= 'FANFL - I0')

plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent')
plt.savefig('../plots/location/FANFL_I1vOG.png')

# %%
plt.plot(FAFL1_I1, label= 'FAFL - I1')
plt.plot(FAFL1, label= 'FAFL - I0')
# plt.plot(FAFL, label= 'FAFL - 0.95')

plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent')
plt.savefig('../plots/location/FAFL_I1vOG.png')

# %%
R0OG,_,R0OGt = recent_rewards('../learning_curves/slow_agent.50.0.01.128.1.0.FA.FL')
R0,_,R0t = recent_rewards('../learning_curves/slow_agent_I1.50.0.01.128.1.0.FA.FL')
R1,_,R1t = recent_rewards('../learning_curves/slow_agent_I1_R1.50.0.01.128.1.0.FA.FL')
R2,_,R2t = recent_rewards('../learning_curves/slow_agent_I1_R2.50.0.01.128.1.0.FA.FL')

# %%
plt.figure(figsize=(10, 5))
plt.plot(R0OG, label= 'R0OG')
plt.plot(R0, label= 'R0')

# plt.ylim(-20,0)
plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent')

# %%
plt.plot(R1, label= 'R1')
plt.plot(R2, label= 'R2')

# plt.ylim(-20,0)
plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent')

# %%
categories = ['R0OG', 'R0', 'R1', 'R2']
results = {
    'R0OG': np.sum(R0OGt),
    'R0': np.sum(R0t),
    'R1': np.sum(R1t),
    'R2': np.sum(R2t)
}
plt.bar(categories, results.values(), color=['red', 'green', 'blue', 'orange'])
plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Value')
plt.title('Slow agent with L1 location | Amount of time slow agent reaches landmark')
