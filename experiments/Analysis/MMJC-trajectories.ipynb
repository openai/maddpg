# %%
from utils import get_rewards_for_last_n_runs, average_and_confidence, plot_with_confidence_interval, plot_multiple_with_confidence_intervals, get_trajectories, plot_trajectories
# Out:
# /Users/Hunter/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Ant 2x4

# %%
base_path = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.2x4.0.001.350.0.99'
base_path_mal = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.2x4.0.001.350.0.99/malfunction'
T1 = get_trajectories(base_path)
T2 = get_trajectories(base_path_mal)
T3 = get_trajectories(base_path_mal)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/l2/bsmxrkc10x736tqpcsz1q6mw0000gp/T/ipykernel_42505/2078245416.py in <module>
#       1 base_path = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.2x4.0.001.350.0.99'
#       2 base_path_mal = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.2x4.0.001.350.0.99/malfunction'
# ----> 3 T1 = get_trajectories(base_path)
#       4 T2 = get_trajectories(base_path_mal)
#       5 T3 = get_trajectories(base_path_mal)
#
# ~/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/Analysis/utils.py in get_trajectories(base_path, date_format)
#     196     recent_directory2 = date_directories2[-1]
#     197
# --> 198     full_path2 = os.path.join(full_path, recent_directory2)
#     199
#     200     with open(os.path.join(full_path2, 'test_test_trajectories.pkl'), 'rb') as f:
#
# NameError: name 'full_path' is not defined

# %%
plot_trajectories(T1, title='Ant2x4', save=True)

# %%
plot_trajectories(T2, title='Ant.2x4.malfunction', save=True)

# %% [markdown]
# # Ant 4x2

# %%
base_path = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99/1-5runs/20240127-161847/'
updated_reward_path = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99/20240206-011238'
base_path_mal = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99/malfunction/20240128-213533/'
T1 = get_trajectories(base_path)
T2 = get_trajectories(base_path_mal)
T3 = get_trajectories(updated_reward_path)

# %%
plot_trajectories(T1, title='Ant.4x2', save=True)
plot_trajectories(T3, title='Ant.4x2.updated', save=True)
plot_trajectories(T2, title='Ant.4x2.malfunction', save=True)

# %% [markdown]
# # Cheetah

# %%
base_path = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99'
base_path_mal = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99/malfunction'
T1 = get_trajectories(base_path)
T2 = get_trajectories(base_path_mal)

# %%
plot_trajectories(T1, title='Ant.4x2', save=True)

# %%
plot_trajectories(T2, title='Ant.4x2.malfunction', save=True)
