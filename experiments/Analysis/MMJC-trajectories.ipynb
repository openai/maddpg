# %%
from utils import get_rewards_for_last_n_runs, average_and_confidence, plot_with_confidence_interval, plot_multiple_with_confidence_intervals, get_trajectories_and_distances, plot_trajectories, plot_distance_distribution
# Out:
# /Users/Hunter/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Ant 2x4

# %%
base_path = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.2x4.0.001.350.0.99'
base_path_mal = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.2x4.0.001.350.0.99/malfunction'
T1,_,_ = get_trajectories(base_path)
T2 = get_trajectories(base_path_mal)
T3 = get_trajectories(base_path_mal)

# %%
plot_trajectories(T1, title='Ant2x4', save=True)

# %%
plot_trajectories(T2, title='Ant.2x4.malfunction', save=True)

# %% [markdown]
# # Ant 4x2

# %%
R2_HE = "/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99/R2/20240209-202744"
R2_mal_HE = "/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99/malfunction/R2/20240210-074547"

T2_HE, T2_ME, T2_d = get_trajectories_and_distances(R2_HE)
# T2_mal_HE, T2_mal_ME, T2_mal_d = get_trajectories_and_distances(R2_mal_HE)

# %%
plot_trajectories(T2_HE, title='Ant.4x2.HE', save=True)
plot_distance_distribution(T2_d, interval_width=5, save=True)
# plot_trajectories(T2_mal_HE, title='Ant.4x2.malfunction.HE', save=True)
# plot_trajectories(T2_ME, title='Ant.4x2.ME', save=True)
# plot_trajectories(T2_mal_ME, title='Ant.4x2.malfunction.ME', save=True)

# %%
R1_HE = "/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99/R1/20240206-045715"
R1_mal_HE = "/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99/malfunction/R1/20240206-161732"

T1_HE, T1_ME = get_trajectories(R1_HE)
T1_mal_HE, T1_mal_ME = get_trajectories(R1_mal_HE)

# %%
plot_trajectories(T1_HE, title='Ant.4x2.HE', save=True)
plot_trajectories(T1_mal_HE, title='Ant.4x2.malfunction.HE', save=True)
plot_trajectories(T1_ME, title='Ant.4x2.ME', save=True)
plot_trajectories(T1_mal_ME, title='Ant.4x2.malfunction.ME', save=True)

# %%
R0_HE = "/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99/R0/20240127-161847"
R0_mal_HE = "/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99/malfunction/R0/20240128-213533"

T0_HE, T0_ME = get_trajectories(R0_HE)
T0_mal_HE, T0_mal_ME = get_trajectories(R0_mal_HE)

# %%
plot_trajectories(T0_HE, title='Ant.4x2.HE', save=True)
plot_trajectories(T0_mal_HE, title='Ant.4x2.malfunction.HE', save=True)
plot_trajectories(T0_ME, title='Ant.4x2.ME', save=True)
plot_trajectories(T0_mal_ME, title='Ant.4x2.malfunction.ME', save=True)

# %% [markdown]
# # Cheetah

# %%
base_path = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99'
base_path_mal = '/Users/Hunter/Development/Academic/UML/RL/Hasenfus-RL/Multi-Agent/maddpg/experiments/learning_curves/Ant.4x2.0.001.350.0.99/malfunction'
T1 = get_trajectories(base_path)
T2 = get_trajectories(base_path_mal)

# %%
plot_trajectories(T1, title='Ant.4x2', save=True)

# %%
plot_trajectories(T2, title='Ant.4x2.malfunction', save=True)
